# %% [markdown]
# # Disclaimer:
# DeepSphere.AI developed these
# materials based on its team’s expertise
# and technical infrastructure, and we
# are sharing these materials strictly for
# learning and research. These learning
# resources may not work on other learning
# infrastructures and DeepSphere.AI
# advises the learners to use these materials
# at their own risk. As needed, we will be
# changing these materials without any
# notification and we have full ownership
# and accountability to make any change
# to these materials.

# %% [markdown]
# # Import Libraries and Install Dependencies

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
from tensorflow.keras.optimizers import SGD
import random

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Activation, Dropout, Dense

nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Class ChatBot
# File Descriptions :
# - DSAI_intents.json - input data as json file
# - DSAI_words.pkl - lemmatized words stored as pickle format
# - DSAI_classes.pkl - classes are stored as pickle format
# - DSAI_chatbot_model.h5 - saved trained model

# %%
class ChatBot:

  def __init__(self, intents): #constructor
  #intents - data from json file
    self.vAR_words=[]
    self.vAR_classes = []
    self.vAR_documents = []
    self.vAR_ignore_words = ['?', '!']
    self.vAR_intents = intents
    self.vAR_lemmatizer = WordNetLemmatizer()
    
    for intent in self.vAR_intents['intents']:
      for pattern in intent['patterns']:

        vAR_w = nltk.word_tokenize(pattern) # take each word and tokenize it
        self.vAR_words.extend(vAR_w)
        self.vAR_documents.append((vAR_w, intent['tag']))  # adding documents

        if intent['tag'] not in self.vAR_classes: # adding classes to our class list
            self.vAR_classes.append(intent['tag'])

    self.vAR_words = [self.vAR_lemmatizer.lemmatize(w.lower()) for w in self.vAR_words if w not in self.vAR_ignore_words]
    self.vAR_words = sorted(list(set(self.vAR_words)))
    self.vAR_classes = sorted(list(set(self.vAR_classes)))

    print(len(self.vAR_documents), "documents")
    print(len(self.vAR_classes), "classes", self.vAR_classes)
    print(len(self.vAR_words), "unique lemmatized words", self.vAR_words)

  def store_object(self): 
    #store/dump lemmatized words and classes as pickle file
    pickle.dump(self.vAR_words,open('../Utility/DSAI_Words.pkl','wb'))
    pickle.dump(self.vAR_classes,open('../Utility/DSAI_Classes.pkl','wb'))

  def initialize_training(self):
    # initializing training data
    # prepare training data
    self.vAR_training = []
    vAR_output_empty = [0] * len(self.vAR_classes)

    for doc in self.vAR_documents:
        vAR_bag = []  # initializing bag of words
        vAR_pattern_words = doc[0]  # list of tokenized words for the pattern
        # lemmatize each word - create base word, in attempt to represent related words
        vAR_pattern_words = [self.vAR_lemmatizer.lemmatize(word.lower()) for word in vAR_pattern_words] 

        # create our bag of words array with 1, if word match found in current pattern
        for w in self.vAR_words:
            vAR_bag.append(1) if w in vAR_pattern_words else vAR_bag.append(0)

        # output is a '0' for each tag and '1' for current tag (for each pattern)
        vAR_output_row = list(vAR_output_empty)
        vAR_output_row[self.vAR_classes.index(doc[1])] = 1

        self.vAR_training.append([vAR_bag, vAR_output_row])
    
    random.shuffle(self.vAR_training)  # shuffle our features and turn into np.array
    self.vAR_training = np.array(self.vAR_training)

  def create_train_test_lists(self):
    # create train and test lists.
    # X - patterns, Y - intents
    self.vAR_train_x = list(self.vAR_training[:,0])
    self.vAR_train_y = list(self.vAR_training[:,1])
    print("Training data created")

  def create_model(self):
    # Number of layers - 3 layers.
    # First layer 128 neurons
    # Second layer 64 neurons 
    # 3rd output layer contains vAR_train_y[0] number of neurons
    # equal to number of intents to predict output intent with softmax
    self.vAR_model = Sequential()
    self.vAR_model.add(Dense(128, input_shape=(len(self.vAR_train_x[0]),), activation='relu'))
    self.vAR_model.add(Dropout(0.5))
    self.vAR_model.add(Dense(64, activation='relu'))
    self.vAR_model.add(Dropout(0.5))
    self.vAR_model.add(Dense(len(self.vAR_train_y[0]), activation='softmax'))

  def compile_model(self):
    # Compile model.
    # Optimizer - Stochastic gradient descent (SGD)
    # Nesterov accelerated gradient gives good results for this model
    vAR_sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    self.vAR_model.compile(loss='categorical_crossentropy', optimizer = vAR_sgd, metrics=['accuracy'])

  def fit_and_save_model(self):
    #fitting the model
    # save the model in .h5 format
    vAR_hist = self.vAR_model.fit(np.array(self.vAR_train_x), np.array(self.vAR_train_y), epochs=200, batch_size=5, verbose=1)
    self.vAR_model.save('../Utility/DSAI_Chatbot_Model.h5', vAR_hist)

    print("Model created")

  def RUN_MODEL(self):
    # method to run all methods
    self.store_object() # method call to store classes and words in pickle format
    self.initialize_training() # method call to prepare training data
    self.create_train_test_lists() #method call to prepare Train-Test list of prepared training data
    self.create_model() #method call to create Sequential model of 3 layers
    # Compile the model with SGD Optimizer, Nesterov Accelerator using Categorical Crossentropy loss and accuracy Metric
    self.compile_model()
    self.fit_and_save_model() #method call to fit the model and save the trained model as DSAI_chatbot_model.h5

# %% [markdown]
# # Import Data
# Input data from DSAI_intents.json is imported

# %%
vAR_data_file = open('../Utility/DSAI_Intents.json').read()
vAR_intents = json.loads(vAR_data_file)

# %% [markdown]
# # Create Object
# Creation of object for class ChatBot with the dataset

# %%
vAR_chat_bot_object = ChatBot(vAR_intents)
# Out:
# 46 documents
# 20 classes ['Textbook', 'access', 'ask', 'askorder', 'benefits', 'career', 'complaint', 'courses', 'createaccount', 'demo', 'goodbye', 'greeting', 'help', 'levels', 'name', 'pay', 'prerequisites', 'registration', 'thanks', 'time']
# 86 unique lemmatized words ["'s", '.', 'a', 'about', 'access', 'account', 'an', 'anyone', 'are', 'at', 'before', 'benefit', 'buy', 'bye', 'call', 'can', 'career', 'certain', 'chapter', 'complaint', 'could', 'course', 'create', 'data', 'demo', 'do', 'doing', 'enroll', 'enrollment', 'for', 'give', 'goodbye', 'hand', 'have', 'hay', 'hello', 'help', 'helpful', 'hey', 'hi', 'how', 'i', 'in', 'is', 'it', 'later', 'level', 'me', 'meet', 'my', 'name', 'need', 'new', 'offered', 'offering', 'online', 'open', 'order', 'pay', 'please', 'prerequisite', 'raise', 'register', 'registered', 'science', 'see', 'service', 'should', 'specific', 'start', 'support', 'take', 'textbook', 'thank', 'thanks', 'that', 'the', 'there', 'time', 'to', 'want', 'what', 'whats', 'why', 'you', 'your']

# %% [markdown]
# # RUN MODEL

# %%
vAR_chat_bot_object.RUN_MODEL()
# Out:
# Training data created
# C:\Users\ravin\AppData\Local\Temp/ipykernel_10540/3318931033.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.vAR_training = np.array(self.vAR_training)
# Epoch 1/200
# C:\Users\ravin\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 10/10 [==============================] - 1s 3ms/step - loss: 3.0377 - accuracy: 0.0652
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0211 - accuracy: 0.0435
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.7979 - accuracy: 0.2391
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.7937 - accuracy: 0.1957
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.7218 - accuracy: 0.1739
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.5860 - accuracy: 0.1957
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.4991 - accuracy: 0.2391
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.3840 - accuracy: 0.3478
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.2154 - accuracy: 0.3043
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1700 - accuracy: 0.3696
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0033 - accuracy: 0.4565
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9825 - accuracy: 0.4348
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9260 - accuracy: 0.5217
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7630 - accuracy: 0.6087
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7568 - accuracy: 0.5000
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6379 - accuracy: 0.5000
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4451 - accuracy: 0.6304
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3216 - accuracy: 0.6522
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5578 - accuracy: 0.6087
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2364 - accuracy: 0.6957
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1939 - accuracy: 0.6304
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1831 - accuracy: 0.6739
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8875 - accuracy: 0.7391
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1353 - accuracy: 0.6522
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9305 - accuracy: 0.7826
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9523 - accuracy: 0.6739
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8440 - accuracy: 0.7609
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.7609
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9619 - accuracy: 0.6522
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.8478
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5789 - accuracy: 0.8043
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.8478
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.9130
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.8261
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5358 - accuracy: 0.8913
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.8696
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4327 - accuracy: 0.8696
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5373 - accuracy: 0.8696
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.8043
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5551 - accuracy: 0.8696
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.8696
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2931 - accuracy: 0.9565
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.9348
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.8913
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.9565
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8478
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8696
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3289 - accuracy: 0.9348
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8913
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9348
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2937 - accuracy: 0.9348
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9783
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3207 - accuracy: 0.9130
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8478
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9130
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2899 - accuracy: 0.9130
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2942 - accuracy: 0.9348
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.8913
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1588 - accuracy: 0.9565
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9348
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9348
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9783
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.9348
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9348
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1191 - accuracy: 0.9565
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9783
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.9130
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3078 - accuracy: 0.8913
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9348
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3116 - accuracy: 0.9130
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.9565
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9348
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1464 - accuracy: 0.9565
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9348
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2038 - accuracy: 0.9565
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9783
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9783
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2019 - accuracy: 0.9348
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9565
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1677 - accuracy: 0.9348
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8696
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9565
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3218 - accuracy: 0.9348
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1742 - accuracy: 0.9348
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2216 - accuracy: 0.9130
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.9348
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9783
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.9348
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.9130
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9565
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9565
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9783
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8913
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9783
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.9783
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2164 - accuracy: 0.9348
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1928 - accuracy: 0.9565
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2040 - accuracy: 0.9130
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1614 - accuracy: 0.9565
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1848 - accuracy: 0.9565
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.8913
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.8913
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1719 - accuracy: 0.9565
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9565
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9783
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1709 - accuracy: 0.9565
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1560 - accuracy: 0.9783
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2032 - accuracy: 0.9565
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9565
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1859 - accuracy: 0.9348
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2239 - accuracy: 0.9130
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9783
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1479 - accuracy: 0.9565
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9565
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9565
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9565
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 0.9783
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9783
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0767 - accuracy: 0.9783
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0551 - accuracy: 0.9783
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9783
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9783
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9348
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9348
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9783
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9783
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9783
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9783
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1623 - accuracy: 0.9348
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1286 - accuracy: 0.9783
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9783
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1560 - accuracy: 0.9565
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9783
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9130
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1082 - accuracy: 0.9565
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2140 - accuracy: 0.8913
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1853 - accuracy: 0.9565
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1376 - accuracy: 0.9348
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0761 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9783
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9783
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1400 - accuracy: 0.9565
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9565
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9565
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9565
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9565
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9783
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9783
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9783
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9783
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9783
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9783
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9565
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1712 - accuracy: 0.9565
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9130
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.9565
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1587 - accuracy: 0.9348
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9130
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9565
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9783
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2016 - accuracy: 0.9565
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9783
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9783
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1537 - accuracy: 0.9565
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Model created

# %% [markdown]
# # Copyright Notice:
# Local and international copyright laws protect
# this material. Repurposing or reproducing
# this material without written approval from
# DeepSphere.AI violates the law.
#
# (c) DeepSphere.AI
