# %% [markdown]
# # Disclaimer:
# DeepSphere.AI developed these
# materials based on its team’s expertise
# and technical infrastructure, and we
# are sharing these materials strictly for
# learning and research. These learning
# resources may not work on other learning
# infrastructures and DeepSphere.AI
# advises the learners to use these materials
# at their own risk. As needed, we will be
# changing these materials without any
# notification and we have full ownership
# and accountability to make any change
# to these materials.
#
# **Author :** Avinash R

# %% [markdown]
# # Import Libraries and Install Dependencies

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
from tensorflow.keras.optimizers import SGD
import random

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Activation, Dropout, Dense

nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Class ChatBot
# File Descriptions :
# - DSAI_intents.json - input data as json file
# - DSAI_words.pkl - lemmatized words stored as pickle format
# - DSAI_classes.pkl - classes are stored as pickle format
# - DSAI_chatbot_model.h5 - saved trained model

# %%
class ChatBot:

  def __init__(self, intents): #constructor
  #intents - data from json file
    self.vAR_words=[]
    self.vAR_classes = []
    self.vAR_documents = []
    self.vAR_ignore_words = ['?', '!']
    self.vAR_intents = intents
    self.vAR_lemmatizer = WordNetLemmatizer()
    
    for intent in self.vAR_intents['intents']:
      for pattern in intent['patterns']:

        vAR_w = nltk.word_tokenize(pattern) # take each word and tokenize it
        self.vAR_words.extend(vAR_w)
        self.vAR_documents.append((vAR_w, intent['tag']))  # adding documents

        if intent['tag'] not in self.vAR_classes: # adding classes to our class list
            self.vAR_classes.append(intent['tag'])

    self.vAR_words = [self.vAR_lemmatizer.lemmatize(w.lower()) for w in self.vAR_words if w not in self.vAR_ignore_words]
    self.vAR_words = sorted(list(set(self.vAR_words)))
    self.vAR_classes = sorted(list(set(self.vAR_classes)))

    print(len(self.vAR_documents), "documents")
    print(len(self.vAR_classes), "classes", self.vAR_classes)
    print(len(self.vAR_words), "unique lemmatized words", self.vAR_words)

  def store_object(self): 
    #store/dump lemmatized words and classes as pickle file
    pickle.dump(self.vAR_words,open('../Utility/DSAI_Words.pkl','wb'))
    pickle.dump(self.vAR_classes,open('../Utility/DSAI_Classes.pkl','wb'))

  def initialize_training(self):
    # initializing training data
    # prepare training data
    self.vAR_training = []
    vAR_output_empty = [0] * len(self.vAR_classes)

    for doc in self.vAR_documents:
        vAR_bag = []  # initializing bag of words
        vAR_pattern_words = doc[0]  # list of tokenized words for the pattern
        # lemmatize each word - create base word, in attempt to represent related words
        vAR_pattern_words = [self.vAR_lemmatizer.lemmatize(word.lower()) for word in vAR_pattern_words] 

        # create our bag of words array with 1, if word match found in current pattern
        for w in self.vAR_words:
            vAR_bag.append(1) if w in vAR_pattern_words else vAR_bag.append(0)

        # output is a '0' for each tag and '1' for current tag (for each pattern)
        vAR_output_row = list(vAR_output_empty)
        vAR_output_row[self.vAR_classes.index(doc[1])] = 1

        self.vAR_training.append([vAR_bag, vAR_output_row])
    
    random.shuffle(self.vAR_training)  # shuffle our features and turn into np.array
    self.vAR_training = np.array(self.vAR_training)

  def create_train_test_lists(self):
    # create train and test lists.
    # X - patterns, Y - intents
    self.vAR_train_x = list(self.vAR_training[:,0])
    self.vAR_train_y = list(self.vAR_training[:,1])
    print("Training data created")

  def create_model(self):
    # Number of layers - 3 layers.
    # First layer 128 neurons
    # Second layer 64 neurons 
    # 3rd output layer contains vAR_train_y[0] number of neurons
    # equal to number of intents to predict output intent with softmax
    self.vAR_model = Sequential()
    self.vAR_model.add(Dense(128, input_shape=(len(self.vAR_train_x[0]),), activation='relu'))
    self.vAR_model.add(Dropout(0.5))
    self.vAR_model.add(Dense(64, activation='relu'))
    self.vAR_model.add(Dropout(0.5))
    self.vAR_model.add(Dense(len(self.vAR_train_y[0]), activation='softmax'))

  def compile_model(self):
    # Compile model.
    # Optimizer - Stochastic gradient descent (SGD)
    # Nesterov accelerated gradient gives good results for this model
    vAR_sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    self.vAR_model.compile(loss='categorical_crossentropy', optimizer = vAR_sgd, metrics=['accuracy'])

  def fit_and_save_model(self):
    #fitting the model
    # save the model in .h5 format
    vAR_hist = self.vAR_model.fit(np.array(self.vAR_train_x), np.array(self.vAR_train_y), epochs=200, batch_size=5, verbose=1)
    self.vAR_model.save('../Utility/DSAI_Chatbot_Model.h5', vAR_hist)

    print("Model created")

  def RUN_MODEL(self):
    # method to run all methods
    self.store_object() # method call to store classes and words in pickle format
    self.initialize_training() # method call to prepare training data
    self.create_train_test_lists() #method call to prepare Train-Test list of prepared training data
    self.create_model() #method call to create Sequential model of 3 layers
    # Compile the model with SGD Optimizer, Nesterov Accelerator using Categorical Crossentropy loss and accuracy Metric
    self.compile_model()
    self.fit_and_save_model() #method call to fit the model and save the trained model as DSAI_chatbot_model.h5

# %% [markdown]
# # Import Data
# Input data from DSAI_intents.json is imported

# %%
vAR_data_file = open('../Utility/DSAI_Intents.json').read()
vAR_intents = json.loads(vAR_data_file)

# %% [markdown]
# # Create Object
# Creation of object for class ChatBot with the dataset

# %%
vAR_chat_bot_object = ChatBot(vAR_intents)
# Out:
# 56 documents
# 15 classes ['Contact', 'Textbook', 'accomplishments', 'ask', 'askorder', 'benefits', 'goodbye', 'greeting', 'help', 'link', 'name', 'newsletter', 'service', 'thanks', 'time']
# 93 unique lemmatized words ["'", "'s", 'a', 'accomplishment', 'achievement', 'any', 'appreciate', 'are', 'be', 'benefit', 'benefitted', 'book', 'bye', 'call', 'can', 'catch', 'certain', 'contact', 'could', 'course', 'deepsphere', 'do', 'doing', 'done', 'during', 'for', 'get', 'give', 'good', 'goodbye', 'guy', 'hand', 'have', 'hay', 'hello', 'help', 'hey', 'hi', 'hope', 'hour', 'how', 'i', 'in', 'is', 'it', 'kind', 'know', 'later', 'let', 'link', 'list', 'me', 'my', 'name', 'need', 'newsletter', 'number', 'of', 'office', 'only', 'order', 'organization', 'please', 'reach', 'really', 'scheduled', 'see', 'send', 'service', 'should', 'signup', 'so', 'staff', 'support', 'taken', 'textbook', 'thank', 'thanks', 'the', 'there', 'time', 'to', 'up', 'website', 'what', 'whats', 'where', 'who', 'will', 'wish', 'you', 'your', 'yours']
# 56 documents
# 15 classes ['Contact', 'Textbook', 'accomplishments', 'ask', 'askorder', 'benefits', 'goodbye', 'greeting', 'help', 'link', 'name', 'newsletter', 'service', 'thanks', 'time']
# 93 unique lemmatized words ["'", "'s", 'a', 'accomplishment', 'achievement', 'any', 'appreciate', 'are', 'be', 'benefit', 'benefitted', 'book', 'bye', 'call', 'can', 'catch', 'certain', 'contact', 'could', 'course', 'deepsphere', 'do', 'doing', 'done', 'during', 'for', 'get', 'give', 'good', 'goodbye', 'guy', 'hand', 'have', 'hay', 'hello', 'help', 'hey', 'hi', 'hope', 'hour', 'how', 'i', 'in', 'is', 'it', 'kind', 'know', 'later', 'let', 'link', 'list', 'me', 'my', 'name', 'need', 'newsletter', 'number', 'of', 'office', 'only', 'order', 'organization', 'please', 'reach', 'really', 'scheduled', 'see', 'send', 'service', 'should', 'signup', 'so', 'staff', 'support', 'taken', 'textbook', 'thank', 'thanks', 'the', 'there', 'time', 'to', 'up', 'website', 'what', 'whats', 'where', 'who', 'will', 'wish', 'you', 'your', 'yours']

# %% [markdown]
# # RUN MODEL

# %%
vAR_chat_bot_object.RUN_MODEL()
# Out:
# Training data created
# C:\Users\ravin\AppData\Local\Temp/ipykernel_7004/3318931033.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.vAR_training = np.array(self.vAR_training)
# Training data created
# C:\Users\ravin\AppData\Local\Temp/ipykernel_7004/3318931033.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.vAR_training = np.array(self.vAR_training)
# Epoch 1/200
# Epoch 1/200
# C:\Users\ravin\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# C:\Users\ravin\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 12/12 [==============================] - 1s 2ms/step - loss: 2.7627 - accuracy: 0.1071
# 12/12 [==============================] - 1s 2ms/step - loss: 2.7627 - accuracy: 0.1071
# Epoch 2/200
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6987 - accuracy: 0.0536
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6987 - accuracy: 0.0536
# Epoch 3/200
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5930 - accuracy: 0.2143
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5930 - accuracy: 0.2143
# Epoch 4/200
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4973 - accuracy: 0.1964
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4973 - accuracy: 0.1964
# Epoch 5/200
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3928 - accuracy: 0.3036
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3928 - accuracy: 0.3036
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3291 - accuracy: 0.2857
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3291 - accuracy: 0.2857
# Epoch 7/200
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3047 - accuracy: 0.2679
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3047 - accuracy: 0.2679
# Epoch 8/200
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1373 - accuracy: 0.3214
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1373 - accuracy: 0.3214
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0908 - accuracy: 0.9821
# Epoch 79/200
# Epoch 79/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9286
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9286
# Epoch 80/200
# Epoch 80/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 81/200
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 82/200
# Epoch 82/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9286
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9286
# Epoch 83/200
# Epoch 83/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9643
# Epoch 84/200
# Epoch 84/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.9464
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.9464
# Epoch 85/200
# Epoch 85/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 86/200
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9643
# Epoch 87/200
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9821
# Epoch 88/200
# Epoch 88/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.9643
# Epoch 89/200
# Epoch 89/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1501 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1501 - accuracy: 0.9464
# Epoch 90/200
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9821
# Epoch 91/200
# Epoch 91/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9643
# Epoch 92/200
# Epoch 92/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9464
# Epoch 93/200
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9821
# Epoch 94/200
# Epoch 94/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.9464
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.9464
# Epoch 95/200
# Epoch 95/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9821
# Epoch 96/200
# Epoch 96/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9821
# Epoch 97/200
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 98/200
# Epoch 98/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9821
# Epoch 99/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9821
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9464
# Epoch 100/200
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9643
# Epoch 101/200
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 102/200
# Epoch 102/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9821
# Epoch 103/200
# Epoch 103/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 0.9643
# Epoch 104/200
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9643
# Epoch 105/200
# Epoch 105/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 0.9821
# Epoch 106/200
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9821
# Epoch 107/200
# Epoch 107/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1179 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1179 - accuracy: 0.9464
# Epoch 108/200
# Epoch 108/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0529 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 109/200
# Epoch 109/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9464
# Epoch 110/200
# Epoch 110/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9643
# Epoch 111/200
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9821
# Epoch 112/200
# Epoch 112/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9464
# Epoch 113/200
# Epoch 113/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9643
# Epoch 114/200
# Epoch 114/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9643
# Epoch 115/200
# Epoch 115/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9464
# Epoch 116/200
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 117/200
# Epoch 117/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 0.9821
# Epoch 118/200
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9821
# Epoch 119/200
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 120/200
# Epoch 120/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9464
# Epoch 121/200
# Epoch 121/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9643
# Epoch 122/200
# Epoch 122/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0722 - accuracy: 0.9643
# Epoch 123/200
# Epoch 123/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9821
# Epoch 124/200
# Epoch 124/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 125/200
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9643
# Epoch 126/200
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 1.0000
# Epoch 127/200
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9821
# Epoch 128/200
# Epoch 128/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0334 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 129/200
# Epoch 129/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9821
# Epoch 131/200
# Epoch 131/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9286
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9286
# Epoch 132/200
# Epoch 132/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9821
# Epoch 133/200
# Epoch 133/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9821
# Epoch 134/200
# Epoch 134/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9821
# Epoch 135/200
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9821
# Epoch 136/200
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9643
# Epoch 137/200
# Epoch 137/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 138/200
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 139/200
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.9821
# Epoch 140/200
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 141/200
# Epoch 141/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0710 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0710 - accuracy: 0.9821
# Epoch 142/200
# Epoch 142/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 143/200
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 144/200
# Epoch 144/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9821
# Epoch 145/200
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9643
# Epoch 146/200
# Epoch 146/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9821
# Epoch 147/200
# Epoch 147/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9643
# Epoch 148/200
# Epoch 148/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 149/200
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 150/200
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9821
# Epoch 151/200
# Epoch 151/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 152/200
# Epoch 152/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0708 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0708 - accuracy: 0.9643
# Epoch 153/200
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9821
# Epoch 154/200
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9821
# Epoch 155/200
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9821
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9821
#  1/12 [=>............................] - ETA: 0s - loss: 0.2521 - accuracy: 0.8000Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9643
# Epoch 157/200
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 158/200
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 0.9821
# Epoch 159/200
# Epoch 159/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 160/200
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9821
# Epoch 161/200
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
#  1/12 [=>............................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9464
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9464
# Epoch 163/200
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 164/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0206 - accuracy: 1.0000Epoch 164/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 165/200
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 166/200
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 167/200
# Epoch 167/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0918 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0918 - accuracy: 0.9643
# Epoch 168/200
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9821
# Epoch 169/200
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9821
# Epoch 170/200
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9821
# Epoch 171/200
# Epoch 171/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9821
# Epoch 172/200
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 173/200
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9821
# Epoch 174/200
# Epoch 174/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 0.9643
# Epoch 175/200
# Epoch 175/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 1.0000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 176/200
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9643
# Epoch 177/200
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 178/200
# Epoch 178/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0675 - accuracy: 0.9821
# Epoch 179/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0675 - accuracy: 0.9821
# Epoch 179/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 180/200
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 181/200
# Epoch 181/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9821
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9821
# Epoch 182/200
# Epoch 182/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9821
# Epoch 183/200
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 184/200
# Epoch 184/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 185/200
# Epoch 185/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9643
# Epoch 186/200
# Epoch 186/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 187/200
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9643
# Epoch 188/200
# Epoch 188/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9821
# Epoch 189/200
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9643
# Epoch 190/200
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 191/200
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9643
# Epoch 192/200
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 193/200
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9821
# Epoch 194/200
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 195/200
# Epoch 195/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0996 - accuracy: 0.9643
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0996 - accuracy: 0.9643
# Epoch 196/200
# Epoch 196/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9643
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9643
# Epoch 197/200
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9821
# Epoch 198/200
# Epoch 198/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1208 - accuracy: 0.9464
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1208 - accuracy: 0.9464
# Epoch 199/200
# Epoch 199/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 200/200
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9821
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9821
# Model created
# Model created

# %% [markdown]
# # Copyright Notice:
# Local and international copyright laws protect
# this material. Repurposing or reproducing
# this material without written approval from
# DeepSphere.AI violates the law.
#
# (c) DeepSphere.AI
